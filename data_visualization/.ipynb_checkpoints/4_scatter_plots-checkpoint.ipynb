# %% [markdown]
# # Preview

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
insurance_filepath = "C:/Users/AndresCervantesNassa/Documents/GitHub/kaggle-courses/data_visualization/data/insurance.csv"
insurance_data = pd.read_csv(insurance_filepath, index_col=False)
insurance_data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'])

# %% [markdown]
# The scatterplot above suggests that body mass index (BMI) and insurance charges are positively correlated, where customers with higher BMI typically also tend to pay more in insurance costs. (This pattern makes sense, since high BMI is typically associated with higher risk of chronic disease.)
#
# To double-check the strength of this relationship, you might like to add a regression line, or the line that best fits the data. We do this by changing the command to **'sns.regplot'**.

# %%
sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges'])

# %% [markdown]
# ## Color-coded scatter plots

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker'])

# %% [markdown]
# This scatter plot shows that while nonsmokers to tend to pay slightly more with increasing BMI, smokers pay MUCH more.
#
# To further emphasize this fact, we can use the **'sns.lmplot'** command to add two regression lines, corresponding to smokers and nonsmokers. (You'll notice that the regression line for smokers has a much steeper slope, relative to the line for nonsmokers!)

# %%
sns.lmplot(x="bmi", y="charges", hue="smoker", data=insurance_data)

# %% [markdown]
# The **sns.lmplot** command above works slightly differently than the commands you have learned about so far:
#
# 1. Instead of setting **x=insurance_data['bmi']** to select the **'bmi'** column in insurance_data, we set **x="bmi"** to specify the name of the column only.
# 2. Similarly, **y="charges"** and **hue="smoker"** also contain the names of columns.
# 3. We specify the dataset with **data=insurance_data**.

# %% [markdown]
# We can adapt the design of the scatter plot to feature a *categorical variable* (like "smoker") on one of the main axes. We'll refer to this plot type as a categorical scatter plot, and we build it with the **sns.swarmplot** command.

# %%
sns.swarmplot(x=insurance_data['smoker'],
              y=insurance_data['charges'])

# %% [markdown]
# # Excercises

# %% [markdown]
# ## Step 1: Load the Data

# %%
candy_filepath = "C:/Users/AndresCervantesNassa/Documents/GitHub/kaggle-courses/data_visualization/data/candy.csv"
candy_data = pd.read_csv(candy_filepath, index_col='id')

# %% [markdown]
# ## Step 2: Review the data

# %%
candy_data
# Out:
#                 competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 0                    100 Grand       Yes     No     Yes             No     No
# 1                 3 Musketeers       Yes     No      No             No    Yes
# 2                    Air Heads        No    Yes      No             No     No
# 3                   Almond Joy       Yes     No      No            Yes     No
# 4                    Baby Ruth       Yes     No     Yes            Yes    Yes
# ..                         ...       ...    ...     ...            ...    ...
# 78                   Twizzlers        No    Yes      No             No     No
# 79                    Warheads        No    Yes      No             No     No
# 80        Welch's Fruit Snacks        No    Yes      No             No     No
# 81  Werther's Original Caramel        No     No     Yes             No     No
# 82                    Whoppers       Yes     No      No             No     No
#
# ...

# %%
# Fill in the line below: Which candy was more popular with survey respondents:
# '3 Musketeers' or 'Almond Joy'?  (Please enclose your answer in single quotes.)
candy_data.loc[candy_data['competitorname']=='3 Musketeers']['winpercent'].values[0] # 67.602936
candy_data.loc[candy_data['competitorname']=='Almond Joy']['winpercent'].values[0] # 50.347546
more_popular = '3 Musketeers'

# Fill in the line below: Which candy has higher sugar content: 'Air Heads'
# or 'Baby Ruth'? (Please enclose your answer in single quotes.)
candy_data.loc[candy_data['competitorname']=='Air Heads']['sugarpercent'].values[0] # 0.90600002
candy_data.loc[candy_data['competitorname']=='Baby Ruth']['sugarpercent'].values[0] # 0.60399997
more_sugar = 'Air Heads'

# %% [markdown]
# ## Step 3: The role of sugar

# %% [markdown]
# Do people tend to prefer candies with higher sugar content?
#
# **Part A**
#
# Create a scatter plot that shows the relationship between 'sugarpercent' (on the horizontal x-axis) and 'winpercent' (on the vertical y-axis). Don't add a regression line just yet -- you'll do that in the next step!

# %%
sns.scatterplot(x=candy_data['sugarpercent'], y=candy_data['winpercent'])

# %% [markdown]
# **Part B**
#
# Does the scatter plot show a strong correlation between the two variables? If so, are candies with more sugar relatively more or less popular with the survey respondents?

# %% [markdown]
# *There's no clear correlation. Popularity is independent from sugar content.*

# %% [markdown]
# ## Step 4: Take a closer look

# %% [markdown]
# **Part A**
#
# Create the same scatter plot you created in Step 3, but now with a regression line!

# %%
sns.regplot(x=candy_data['sugarpercent'], y=candy_data['winpercent'])

# %% [markdown]
# **Part B**
#
# According to the plot above, is there a slight correlation between 'winpercent' and 'sugarpercent'? What does this tell you about the candy that people tend to prefer?

# %% [markdown]
# *There's actually a slight correlation. People slightly tend to prefer more sugar in their candies.*

# %% [markdown]
# ## Step 5: Chocolate!

# %%
# Scatter plot showing the relationship between 'pricepercent', 'winpercent', and 'chocolate'
sns.scatterplot(x=candy_data['pricepercent'], y=candy_data['winpercent'], hue=candy_data['chocolate'])

# %% [markdown]
# ## Step 6: Investigate chocolate

# %% [markdown]
# **Part A**
#
# Create the same scatter plot you created in Step 5, but now with two regression lines, corresponding to (1) chocolate candies and (2) candies without chocolate.

# %%
sns.lmplot(x="pricepercent", y="winpercent", hue="chocolate", data=candy_data)

# %% [markdown]
# **Part B**
#
# Using the regression lines, what conclusions can you draw about the effects of chocolate and price on candy popularity?

# %% [markdown]
# *Chocolate candies cost more than those that don't have any chocolate. Also, the tend to be more popular the more expensive they are.*

# %% [markdown]
# ## Step 7: Everybody loves chocolate.

# %% [markdown]
# **Part A**
#
# Create a categorical scatter plot to highlight the relationship between 'chocolate' and 'winpercent'. Put 'chocolate' on the (horizontal) x-axis, and 'winpercent' on the (vertical) y-axis.

# %%
sns.swarmplot(x=candy_data['chocolate'],
              y=candy_data['winpercent'])

# %% [markdown]
# **Part B**
#
# You decide to dedicate a section of your report to the fact that chocolate candies tend to be more popular than candies without chocolate. Which plot is more appropriate to tell this story: the plot from Step 6, or the plot from Step 7?

# %% [markdown]
# *I think that the last plot is easier to digest and to show that chocolate candies are more popular. The plot from Step 6 conveys far more information that could distract from the main point.*
